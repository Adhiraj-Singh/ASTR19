# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = []
x = np.linspace(0,1,100)

# %%
def expoChange(x):
    return math.exp(x)

# %%
y = []
for z in x:
    y.append(math.exp(z))

# %%
plt.plot(x,y)
plt.title("Adhiraj Singh Graph")
plt.xlabel("Time [Milliseconds]")
plt.ylabel("Awesomeness")
plt.show()
